# %%
# !pip install tensorflow

# %%
# !pip install keras

# %%
import numpy as np
import pandas as pd

# %%
# importing neccessary model for implementation of ANN
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
gas = pd.read_csv('I:\\Assigment - Data Science\\Neural Network\\gas_turbines.csv',delimiter =',')

# %%
gas
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# ...

# %%
gas = gas[['AT','AP','AH','AFDP','GTEP','TIT','TAT','CDP','CO','NOX','TEY']]

# %%
gas
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     CDP      CO  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  10.605  3.1547
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  10.598  3.2363
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  10.601  3.2012
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  10.606  3.1923
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  10.612  3.2484
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  10.400  4.5186
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  10.433  4.8470
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  10.483  7.9632
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  10.533  6.2494
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  10.583  4.9816
#
#           NOX     TEY
# ...

# %%
label_encoder = preprocessing.LabelEncoder()
gas['AT'] = label_encoder.fit_transform(gas['AT'])

# %%
label_encoder = preprocessing.LabelEncoder()
gas['AP'] = label_encoder.fit_transform(gas['AP'])

# %%
label_encoder = preprocessing.LabelEncoder()
gas['AH'] = label_encoder.fit_transform(gas['AH'])

# %%
label_encoder = preprocessing.LabelEncoder()
gas['AFDP'] = label_encoder.fit_transform(gas['AFDP'])

# %%
label_encoder = preprocessing.LabelEncoder()
gas['GTEP'] = label_encoder.fit_transform(gas['GTEP'])

# %%
label_encoder = preprocessing.LabelEncoder()
gas['TIT'] = label_encoder.fit_transform(gas['TIT'])

# %%
label_encoder = preprocessing.LabelEncoder()
gas['TAT'] = label_encoder.fit_transform(gas['TAT'])

# %%
label_encoder = preprocessing.LabelEncoder()
gas['CDP'] = label_encoder.fit_transform(gas['CDP'])

# %%
label_encoder = preprocessing.LabelEncoder()
gas['TEY'] = label_encoder.fit_transform(gas['TEY'])

# %%
label_encoder = preprocessing.LabelEncoder()
gas['CO'] = label_encoder.fit_transform(gas['CO'])

# %%
label_encoder = preprocessing.LabelEncoder()
gas['NOX'] = label_encoder.fit_transform(gas['NOX'])

# %%
gas.isnull().sum().sum()
# Out:
# 0

# %%
gas
# Out:
#          AT   AP     AH  AFDP  GTEP  TIT   TAT  CDP     CO    NOX  TEY
# 0      1230  292  12092  2208   787  292  2285  461  10695  10885  707
# 1      1199  297  12149  2207   842  293  2285  454  10775  10892  709
# 2      1251  301  11882  2148   883  294  2272  457  10746  10835  708
# 3      1334  305  11699  2138   892  296  2284  462  10738  10875  709
# 4      1505  310  11676  2197   871  297  2283  468  10782  10774  709
# ...     ...  ...    ...   ...   ...  ...   ...  ...    ...    ...  ...
# 15034  2278  269  12369  2376   382  197  1964  256  11809  10229  491
# 15035  1732  272  12467  2230   577  163  1742  289  12015  10317  508
# 15036  1433  276  12533  2121   675   83  1247  339  12818  11571  352
# 15037  1302  281  12449  2009   545  135  1583  389  12579  11636  406
# 15038  1266  285  12227  1953   485  199  1939  439  12087  11620  488
#
# [15039 rows x 11 columns]

# %%
X = gas.iloc[:,0:10]
Y = gas.iloc[:,-1]

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.3)

# %% [markdown]
# ## First Model
# No. of Input features = 10
# No of Hidden layer = 1
# No. of hidden neuron = 12
# No. of dimension of output = 1

# %%
column_names = list(gas.columns)
predictors = column_names[0:10]
target = column_names[-1]
predictors
# Out:
# ['AT', 'AP', 'AH', 'AFDP', 'GTEP', 'TIT', 'TAT', 'CDP', 'CO', 'NOX']

# %%
def prep_model(hidden_dim):
    model = Sequential()
    for i in range(1,len(hidden_dim)-1):
        if (i==1):
            model.add(Dense(hidden_dim[i],input_dim=hidden_dim[0],kernel_initializer="normal",activation="relu"))
        else:
            model.add(Dense(hidden_dim[i],activation="relu"))
    # for the output layer we are not adding any activation function as 
    # the target variable is continuous variable 
    model.add(Dense(hidden_dim[-1]))
    # loss ---> loss function is means squared error to compare the output and estimated output
    # optimizer ---> adam
    # metrics ----> mean squared error - error for each epoch on entire data set 
    model.compile(loss="mean_squared_error",optimizer="adam",metrics = ["mse"])
    return (model)

# %%
first_model = prep_model([10,100,1])
first_model.fit((gas.iloc[:,0:10]),(gas.iloc[:,-1]),epochs=20)
# Out:
# Epoch 1/20
# 470/470 [==============================] - 2s 1ms/step - loss: 798452.6119 - mse: 798452.6119
# Epoch 2/20
# 470/470 [==============================] - 0s 1ms/step - loss: 8635.0329 - mse: 8635.0329
# Epoch 3/20
# 470/470 [==============================] - 0s 1ms/step - loss: 7356.7392 - mse: 7356.7392
# Epoch 4/20
# 470/470 [==============================] - 0s 1ms/step - loss: 5915.6563 - mse: 5915.6563
# Epoch 5/20
# 470/470 [==============================] - 0s 1ms/step - loss: 5692.7688 - mse: 5692.7688
# Epoch 6/20
# 470/470 [==============================] - 0s 994us/step - loss: 5375.3146 - mse: 5375.3146
# Epoch 7/20
# 470/470 [==============================] - 0s 936us/step - loss: 4970.4090 - mse: 4970.4090
# Epoch 8/20
# 470/470 [==============================] - 0s 994us/step - loss: 4859.2329 - mse: 4859.2329
# Epoch 9/20
# 470/470 [==============================] - 0s 921us/step - loss: 5002.1140 - mse: 5002.1140
# Epoch 10/20
# ...

# %%
first_model = prep_model([10,100,1])

# %%
pred_train = first_model.predict(np.array(train[predictors]))
pred_train = pd.Series([i[0] for i in pred_train])
rmse_value = np.sqrt(np.mean((pred_train-train[target])**2))
rmse_value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-03e4278c30bc> in <module>
# ----> 1 pred_train = first_model.predict(np.array(train[predictors]))
#       2 pred_train = pd.Series([i[0] for i in pred_train])
#       3 rmse_value = np.sqrt(np.mean((pred_train-train[target])**2))
#       4 rmse_value
#
# NameError: name 'train' is not defined
